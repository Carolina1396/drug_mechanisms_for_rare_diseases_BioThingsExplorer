# %%
#Import libraries
import json
import pandas as pd
from pyvis.network import Network

# %%
# Define function to Extract subject-predicate-object values 
def sub_pre_obj (my_dir):
    df_list = []
    with open (my_dir) as f:
            data = json.load(f)
    for rec in data["message"]["knowledge_graph"]["edges"].values():
        #Empty data frame 
        column_names = ["subject", "predicate", "object", "original_object_name", 'original_subject_name', 'biolink:original_predicate']
        df = pd.DataFrame(columns = column_names)
        for att in rec['attributes']:
            if att['attribute_type_id'] in ["original_object_name", 'original_subject_name', 'biolink:original_predicate']:
                df[att['attribute_type_id']] = [att['value']]
        df["subject"]=rec["subject"], 
        df["predicate"]=rec["predicate"], 
        df["object"]=rec ["object"]
        df_list.append(df)
    df_all = pd.concat(df_list)
    return (df_all)

# %% [markdown]
# ### Pulmonary hypertension - Phenotypic Features - Iloprost

# %%
#Import file 
my_dir= "../results/Disease_SmallMolecule_PhenotypicFeature_/MONDO:0015924_Disease_SmallMolecule_PhenotypicFeature_CHEMBL494"

# %%
df_all = sub_pre_obj(my_dir)
set_obj = df_all[0:5] #Select sobe subjects 
set_obj
# Out:
#          subject           predicate      object     original_object_name  \
# 0  MONDO:0015924  biolink:related_to  HP:0002105  Hypertension, Pulmonary
# 0  MONDO:0015924  biolink:related_to  HP:0012378                  Fatigue
# 0  MONDO:0015924  biolink:related_to  HP:0100749               Chest Pain
# 0  MONDO:0015924  biolink:related_to  HP:0002094  Hypertension, Pulmonary
# 0  MONDO:0015924  biolink:related_to  HP:0025406  Hypertension, Pulmonary
#
#      original_subject_name biolink:original_predicate
# 0               Hemoptysis                     CAUSES
# 0  Hypertension, Pulmonary              COEXISTS_WITH
# 0  Hypertension, Pulmonary                     CAUSES
# 0                  Dyspnea                  DIAGNOSES
# 0                 Asthenia                  DIAGNOSES

# %%
#Select subjects that has object of interest. That way we can connect them 
set_sub = df_all[df_all["subject"].isin(["HP:0002105","HP:0012378" , "HP:0100749","HP:0002094",  "HP:0025406"])]
set_sub
# Out:
#       subject                        predicate                    object  \
# 0  HP:0002105  biolink:adverse_event_caused_by  PUBCHEM.COMPOUND:5311181
# 0  HP:0100749  biolink:adverse_event_caused_by  PUBCHEM.COMPOUND:5311181
# 0  HP:0002094  biolink:adverse_event_caused_by  PUBCHEM.COMPOUND:5311181
# 0  HP:0012378  biolink:adverse_event_caused_by  PUBCHEM.COMPOUND:5311181
# 0  HP:0025406  biolink:adverse_event_caused_by  PUBCHEM.COMPOUND:5311181
#
#   original_object_name original_subject_name biolink:original_predicate
# 0                  NaN                   NaN                        NaN
# 0                  NaN                   NaN                        NaN
# 0                  NaN                   NaN                        NaN
# 0                  NaN                   NaN                        NaN
# 0                  NaN                   NaN                        NaN

# %%
relations = pd.concat([set_obj, set_sub])
relations
# Out:
#          subject                        predicate                    object  \
# 0  MONDO:0015924               biolink:related_to                HP:0002105
# 0  MONDO:0015924               biolink:related_to                HP:0012378
# 0  MONDO:0015924               biolink:related_to                HP:0100749
# 0  MONDO:0015924               biolink:related_to                HP:0002094
# 0  MONDO:0015924               biolink:related_to                HP:0025406
# 0     HP:0002105  biolink:adverse_event_caused_by  PUBCHEM.COMPOUND:5311181
# 0     HP:0100749  biolink:adverse_event_caused_by  PUBCHEM.COMPOUND:5311181
# 0     HP:0002094  biolink:adverse_event_caused_by  PUBCHEM.COMPOUND:5311181
# 0     HP:0012378  biolink:adverse_event_caused_by  PUBCHEM.COMPOUND:5311181
# 0     HP:0025406  biolink:adverse_event_caused_by  PUBCHEM.COMPOUND:5311181
#
#       original_object_name    original_subject_name biolink:original_predicate
# 0  Hypertension, Pulmonary               Hemoptysis                     CAUSES
# 0                  Fatigue  Hypertension, Pulmonary              COEXISTS_WITH
# 0               Chest Pain  Hypertension, Pulmonary                     CAUSES
# 0  Hypertension, Pulmonary                  Dyspnea                  DIAGNOSES
# 0  Hypertension, Pulmonary                 Asthenia                  DIAGNOSES
# 0                      NaN                      NaN                        NaN
# 0                      NaN                      NaN                        NaN
# 0                      NaN                      NaN                        NaN
# 0                      NaN                      NaN                        NaN
# 0                      NaN                      NaN                        NaN

# %%
#Networkx visualization 
got_net = Network(height='750px', width='100%', bgcolor='#222222', font_color='black')

# set the physics layout of the network

sources = relations['subject']
targets =relations["object"]
weights = relations["predicate"]

edge_data = zip(sources, targets, weights)

for e in edge_data:
    src = e[0]
    dst = e[1]
    w = e[2]

    got_net.add_node(src, src, title=src)
    got_net.add_node(dst, dst, title=dst)
    got_net.add_edge(src, dst, value=w)

neighbor_map = got_net.get_adj_list()

# add neighbor data to node hover data
for node in got_net.nodes:
    node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
    node['value'] = len(neighbor_map[node['id']])

got_net.show("MONDO:0015924-pheno.html")

# %% [markdown]
# ### Pulmonary hypertension - Genes - Iloprost

# %%
my_dir_gene_com= "../results/Disease_SmallMolecule_Gene_//MONDO:0015924_Disease_SmallMolecule_Gene_CHEMBL494"

# %%
df_all = sub_pre_obj(my_dir_gene_com)
set_obj = df_all[0:4] #Select sobe subjects 
set_obj
# Out:
#          subject           predicate         object     original_object_name  \
# 0  MONDO:0015924  biolink:related_to  NCBIGene:6347  Hypertension, Pulmonary
# 0  MONDO:0015924  biolink:related_to  NCBIGene:3717  Hypertension, Pulmonary
# 0  MONDO:0015924  biolink:related_to   NCBIGene:284  Hypertension, Pulmonary
# 0  MONDO:0015924  biolink:related_to  NCBIGene:3689  Hypertension, Pulmonary
#
#   original_subject_name biolink:original_predicate
# 0             CCL2 gene            ASSOCIATED_WITH
# 0             JAK2 gene            ASSOCIATED_WITH
# 0           ANGPT1 gene            ASSOCIATED_WITH
# 0            ITGB2 gene            ASSOCIATED_WITH

# %%
set_sub = df_all[df_all["subject"].isin(["NCBIGene:6347", "NCBIGene:3717", "NCBIGene:284", "NCBIGene:3689"])]
set_sub
# Out:
#          subject                                      predicate  \
# 0   NCBIGene:284  biolink:entity_positively_regulated_by_entity
# 0  NCBIGene:3717  biolink:entity_negatively_regulated_by_entity
# 0  NCBIGene:3689  biolink:entity_negatively_regulated_by_entity
# 0  NCBIGene:6347  biolink:entity_negatively_regulated_by_entity
#
#                      object original_object_name original_subject_name  \
# 0  PUBCHEM.COMPOUND:5311181                  NaN                   NaN
# 0  PUBCHEM.COMPOUND:5311181                  NaN                   NaN
# 0  PUBCHEM.COMPOUND:5311181                  NaN                   NaN
# 0  PUBCHEM.COMPOUND:5311181                  NaN                   NaN
#
#   biolink:original_predicate
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN

# %%
relations = pd.concat([set_obj, set_sub])
relations
# Out:
#          subject                                      predicate  \
# 0  MONDO:0015924                             biolink:related_to
# 0  MONDO:0015924                             biolink:related_to
# 0  MONDO:0015924                             biolink:related_to
# 0  MONDO:0015924                             biolink:related_to
# 0   NCBIGene:284  biolink:entity_positively_regulated_by_entity
# 0  NCBIGene:3717  biolink:entity_negatively_regulated_by_entity
# 0  NCBIGene:3689  biolink:entity_negatively_regulated_by_entity
# 0  NCBIGene:6347  biolink:entity_negatively_regulated_by_entity
#
#                      object     original_object_name original_subject_name  \
# 0             NCBIGene:6347  Hypertension, Pulmonary             CCL2 gene
# 0             NCBIGene:3717  Hypertension, Pulmonary             JAK2 gene
# 0              NCBIGene:284  Hypertension, Pulmonary           ANGPT1 gene
# 0             NCBIGene:3689  Hypertension, Pulmonary            ITGB2 gene
# 0  PUBCHEM.COMPOUND:5311181                      NaN                   NaN
# 0  PUBCHEM.COMPOUND:5311181                      NaN                   NaN
# 0  PUBCHEM.COMPOUND:5311181                      NaN                   NaN
# 0  PUBCHEM.COMPOUND:5311181                      NaN                   NaN
#
#   biolink:original_predicate
# 0            ASSOCIATED_WITH
# 0            ASSOCIATED_WITH
# 0            ASSOCIATED_WITH
# 0            ASSOCIATED_WITH
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN

# %%
got_net = Network(height='750px', width='100%', bgcolor='#222222', font_color='black')

# set the physics layout of the network

sources = relations['subject']
targets = relations["object"]
weights = relations["predicate"]

edge_data = zip(sources, targets, weights)

for e in edge_data:
    src = e[0]
    dst = e[1]
    w = e[2]

    got_net.add_node(src, src, title=src)
    got_net.add_node(dst, dst, title=dst)
    got_net.add_edge(src, dst, value=w)

neighbor_map = got_net.get_adj_list()

# add neighbor data to node hover data
for node in got_net.nodes:
    node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
    node['value'] = len(neighbor_map[node['id']])

got_net.show("MONDO:0015924-gene.html")

# %% [markdown]
# ### Pulmonary hypertension - Genetic variants - Iloprost

# %%
my_dir_var= "../results/Disease_SmallMolecule_SequenceVariant_Gene_/MONDO:0015924_Disease_SmallMolecule_SequenceVariant_Gene_CHEMBL494"

# %%
df_all = sub_pre_obj(my_dir_var)
df_all
# Out:
#              subject                                      predicate  \
# 0      MONDO:0015924                             biolink:related_to
# 0  DBSNP:rs779721443                 biolink:is_sequence_variant_of
# 0      NCBIGene:4090  biolink:entity_negatively_regulated_by_entity
#
#                      object original_object_name original_subject_name  \
# 0         DBSNP:rs779721443                  NaN                   NaN
# 0             NCBIGene:4090                  NaN                   NaN
# 0  PUBCHEM.COMPOUND:5311181                  NaN                   NaN
#
#   biolink:original_predicate
# 0                        NaN
# 0                        NaN
# 0                        NaN

# %%
got_net = Network(height='750px', width='100%', bgcolor='#222222', font_color='black')

# set the physics layout of the network

sources = df_all['subject']
targets =df_all["object"]
weights = df_all["predicate"]

edge_data = zip(sources, targets, weights)

for e in edge_data:
    src = e[0]
    dst = e[1]
    w = e[2]

    got_net.add_node(src, src, title=src)
    got_net.add_node(dst, dst, title=dst)
    got_net.add_edge(src, dst, title= w)

neighbor_map = got_net.get_adj_list()

# add neighbor data to node hover data
for node in got_net.nodes:
    node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
    node['value'] = len(neighbor_map[node['id']])

got_net.show("MONDO:0015924_genetic_variants.html")

# %% [markdown]
# ### Pulmonary hypertension - Phenotypic Features - Genes- Iloprost

# %%
my_dir_pheno_gene= "../results/Disease_SmallMolecule_PhenotypicFeature_Gene_/MONDO:0015924_Disease_SmallMolecule_PhenotypicFeature_Gene_CHEMBL494"

# %%
df_all = sub_pre_obj(my_dir_pheno_gene)
df_all[0:25]
# Out:
#          subject           predicate         object  \
# 0  MONDO:0015924  biolink:related_to     HP:0002172
# 0  MONDO:0015924  biolink:related_to     HP:0002375
# 0  MONDO:0015924  biolink:related_to     HP:0030148
# 0  MONDO:0015924  biolink:related_to     HP:0004326
# 0  MONDO:0015924  biolink:related_to     HP:0002105
# 0  MONDO:0015924  biolink:related_to     HP:0012378
# 0  MONDO:0015924  biolink:related_to  MONDO:0005466
# 0  MONDO:0015924  biolink:related_to     HP:0100749
# 0  MONDO:0015924  biolink:related_to  UMLS:C0278134
# 0  MONDO:0015924  biolink:related_to     HP:0025143
# 0  MONDO:0015924  biolink:related_to  UMLS:C0427008
# 0  MONDO:0015924  biolink:related_to     HP:0002094
# 0  MONDO:0015924  biolink:related_to  UMLS:C0231239
# 0  MONDO:0015924  biolink:related_to     HP:0003552
# 0  MONDO:0015924  biolink:related_to  MONDO:0002050
# 0  MONDO:0015924  biolink:related_to  UMLS:C0232605
# 0  MONDO:0015924  biolink:related_to  UMLS:C0242706
# 0  MONDO:0015924  biolink:related_to     HP:0002039
# 0  MONDO:0015924  biolink:related_to     HP:0025406
# 0  MONDO:0015924  biolink:related_to  MONDO:0004900
# 0  MONDO:0015924  biolink:related_to     HP:0001279
# 0  MONDO:0015924  biolink:related_to     HP:0002875
# 0  MONDO:0015924  biolink:related_to  UMLS:C0948600
# 0  MONDO:0015924  biolink:related_to     HP:0001681
# 0  MONDO:0015924  biolink:related_to     HP:0012416
#
#               original_object_name           original_subject_name  \
# 0  Pulmonary arterial hypertension                       Imbalance
# 0          Hypertension, Pulmonary                     Hypokinesia
# 0          Hypertension, Pulmonary                    Heart murmur
# 0          Hypertension, Pulmonary                        Cachexia
# 0          Hypertension, Pulmonary                      Hemoptysis
# 0                          Fatigue         Hypertension, Pulmonary
# 0          Hypertension, Pulmonary                 Hypersomnolence
# 0                       Chest Pain         Hypertension, Pulmonary
# 0          Hypertension, Pulmonary               Lack of sensation
# 0          Hypertension, Pulmonary                          Chills
# 0          Hypertension, Pulmonary                       Stiffness
# 0          Hypertension, Pulmonary                         Dyspnea
# 0                      Fluctuation         Hypertension, Pulmonary
# 0          Hypertension, Pulmonary              Muscular stiffness
# 0  Pulmonary arterial hypertension             Depressive Symptoms
# 0          Hypertension, Pulmonary   Regurgitates after swallowing
# 0          Hypertension, Pulmonary                       Hyperoxia
# 0          Hypertension, Pulmonary                        Anorexia
# 0          Hypertension, Pulmonary                        Asthenia
# 0          Hypertension, Pulmonary                       Dizziness
# 0                          Syncope  Primary pulmonary hypertension
# 0          Hypertension, Pulmonary             Dyspnea on exertion
# 0          Hypertension, Pulmonary                   Organ failure
# 0  Pulmonary arterial hypertension                 Angina Pectoris
# 0          Hypertension, Pulmonary                     Hypercapnia
#
#   biolink:original_predicate
# 0           MANIFESTATION_OF
# 0                     CAUSES
# 0            ASSOCIATED_WITH
# 0            ASSOCIATED_WITH
# 0                     CAUSES
# 0              COEXISTS_WITH
# 0            ASSOCIATED_WITH
# 0                     CAUSES
# 0              COEXISTS_WITH
# 0            ASSOCIATED_WITH
# 0              COEXISTS_WITH
# 0                  DIAGNOSES
# 0                     CAUSES
# 0                     CAUSES
# 0            ASSOCIATED_WITH
# 0                     CAUSES
# 0                PREDISPOSES
# 0            ASSOCIATED_WITH
# 0                  DIAGNOSES
# 0            ASSOCIATED_WITH
# 0                     CAUSES
# 0                     CAUSES
# 0            ASSOCIATED_WITH
# 0            ASSOCIATED_WITH
# 0                PREDISPOSES

# %%
got_net = Network(height='750px', width='100%', bgcolor='#222222', font_color='black')

# set the physics layout of the network

sources = df_all['subject']
targets =df_all["object"]
weights = df_all["predicate"]

edge_data = zip(sources, targets, weights)

for e in edge_data:
    src = e[0]
    dst = e[1]
    w = e[2]

    got_net.add_node(src, src, title=src)
    got_net.add_node(dst, dst, title=dst)
    got_net.add_edge(src, dst, value=w)

neighbor_map = got_net.get_adj_list()

# add neighbor data to node hover data
for node in got_net.nodes:
    node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
    node['value'] = len(neighbor_map[node['id']])

got_net.show("MONDO:0015924-pheno-gene.html")

# %% [markdown]
# ### Pulmonary hypertension - Biological Process - Genes- Iloprost

# %%
my_dir_bp= "../results/Disease_SmallMolecule_BiologicalProcessOrActivity_/MONDO:0015924_Disease_SmallMolecule_BiologicalProcessOrActivity_CHEMBL494"

# %%
df_all = sub_pre_obj(my_dir_bp)
df_all
# Out:
#          subject                predicate                    object  \
# 0  MONDO:0015924  biolink:correlated_with                GO:0051344
# 0  MONDO:0015924  biolink:correlated_with                GO:0042311
# 0     GO:0042311  biolink:correlated_with  PUBCHEM.COMPOUND:5311181
# 0     GO:0051344  biolink:correlated_with  PUBCHEM.COMPOUND:5311181
#
#   original_object_name original_subject_name biolink:original_predicate
# 0                  NaN                   NaN                        NaN
# 0                  NaN                   NaN                        NaN
# 0                  NaN                   NaN                        NaN
# 0                  NaN                   NaN                        NaN

# %%
got_net = Network(height='750px', width='100%', bgcolor='#222222', font_color='black')

# set the physics layout of the network

sources = df_all['subject']
targets =df_all["object"]
weights = df_all["predicate"]

edge_data = zip(sources, targets, weights)

for e in edge_data:
    src = e[0]
    dst = e[1]
    w = e[2]

    got_net.add_node(src, src, title=src)
    got_net.add_node(dst, dst, title=dst)
    got_net.add_edge(src, dst, value=w)

neighbor_map = got_net.get_adj_list()

# add neighbor data to node hover data
for node in got_net.nodes:
    node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
    node['value'] = len(neighbor_map[node['id']])

got_net.show("MONDO:0015924_biological_process.html")
